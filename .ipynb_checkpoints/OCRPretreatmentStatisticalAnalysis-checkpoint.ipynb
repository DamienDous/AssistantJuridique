# %%
# Affichage du WER moyen par variante de prétraitement
classement = df.groupby('parametres_traitement')['cer'].mean().sort_values()
display(classement)
# Out:
# parametres_traitement
# -resize 200% -colorspace Gray -median 3 -normalize                                       0.663551
# -resize 200% -colorspace Gray -normalize -auto-threshold Otsu                            0.669708
# -resize 200% -colorspace Gray -auto-gamma -auto-threshold Otsu                           0.676827
# -resize 200% -colorspace Gray -normalize -deskew 40% -auto-threshold Otsu                0.687980
# -resize 200% -colorspace Gray -auto-level -normalize -auto-threshold Otsu                0.700707
# -resize 200% -colorspace Gray -normalize -sharpen 0x1 -auto-threshold Otsu               0.703228
# -resize 200% -colorspace Gray -deskew 40% -normalize -auto-threshold Otsu                0.726783
# -resize 200% -colorspace Gray -normalize -background white -flatten                      0.737246
# -resize 200% -colorspace Gray -blur 1x1 -auto-threshold Otsu                             0.747103
# -resize 200% -colorspace Gray -white-threshold 80% -normalize -auto-threshold Otsu       0.753717
# -resize 200% -colorspace Gray -contrast-stretch 0.3%x0.3% -auto-threshold Otsu           0.759590
# -resize 200% -colorspace Gray -normalize -enhance                                        0.771622
# -resize 200% -colorspace Gray -normalize -auto-threshold Triangle                        0.811619
# -resize 200% -colorspace Gray -normalize -sharpen 0x2 -despeckle -auto-threshold Otsu    0.827130
# -resize 200% -colorspace Gray -normalize -adaptive-sharpen 0x2 -auto-threshold Otsu      0.856863
# -resize 200% -colorspace Gray -auto-level -sharpen 0x1                                   0.903364
# Name: cer, dtype: float64

# %%
import pandas as pd

df = pd.read_csv("DB/currentFolder/out/score_final.csv")
display(df.head())
print(df.shape)
# Out:
#                                              fichier                cat   cer  \
# 0  e41f7bf4b17794c3b4c9190057edec1e9c560e67fe482e...  financial_reports  0.02
# 1  e41f7bf4b17794c3b4c9190057edec1e9c560e67fe482e...  financial_reports  0.03
# 2  56f284063b796db005fe021fe6f54ed7f0d10388815a88...            manuals  0.17
# 3  601febfd3972ff8015d3f121d6716a9b915533f309883a...            patents  0.48
# 4  42fdccb4bfa1140581ba427f7da4d7b8a53bcb03e5e055...            manuals  0.62
#
#    jacc_multi  ratios_mean                              parametres_traitement
# 0        0.94         0.64  -resize 200% -colorspace Gray -normalize -back...
# 1        0.83         0.63  -resize 200% -colorspace Gray -normalize -auto...
# 2        0.88         0.56  -resize 200% -colorspace Gray -normalize -back...
# 3        0.58         0.53  -resize 200% -colorspace Gray -normalize -back...
# 4        0.48         0.30  -resize 200% -colorspace Gray -normalize -back...
# (1811, 6)

# %%
df.loc[df['cer'] > 2, 'cer'] = 2
# Out:
# C:\Users\damien_dous\AppData\Local\Temp\ipykernel_16664\116326663.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['cer'] > 2]['cer'] = 2

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,8))
sns.boxplot(data=df, x="parametres_traitement", y="cer")
plt.xticks(rotation=60, ha="right")
plt.ylim(0, 1.2)  # Limite l’axe y à 1.2
plt.title("Score CER par variante (outliers masqués)")
plt.show()

# %%
# 3. Afficher la variante la plus performante pour chaque page selon le WER
idx_best_wer = df.groupby('fichier')['cer'].idxmin()
df.loc[idx_best_wer].sort_values('cer')
# Out:
#                                                 fichier                   cat  \
# 963   4d9297edf17763150c04fb2b49a4b28791cba63b1d1189...  laws_and_regulations
# 7     04f1fe91787710fb9d28ae9dbb840a72f9a4aa47082b5c...               manuals
# 82    38dcda0e37c4b5acc80f9952e97c213013154590f83b61...               manuals
# 1389  090e3d2af31a228063f226be41958b999bdca339ff9c33...               manuals
# 976   7672298edc56d3ce972d879f345e70331b103a9f8ac6c4...               manuals
# ...                                                 ...                   ...
# 528   2a7d2bb7cd6eb6c9c2790ac3826264dd44989353a5eaaa...   scientific_articles
# 125   54136c909661ea088d7c825d90289eef65546501748894...  laws_and_regulations
# 16    c89de3e108a8ff86a04af6d817978d037daab718a66d5d...     financial_reports
# 524   b9884c5e29975ef8ce92f758b8fccbcfba1df6ab463848...     financial_reports
# 1644  ce14a9e93aadabb89005c15a8b594e617f7f1bf1b507cb...               patents
#
#        cer  jacc_multi  ratios_mean  \
# 963   0.00        1.00         0.60
# 7     0.01        1.00         0.63
# 82    0.01        0.93         0.61
# 1389  0.01        0.99         0.63
# 976   0.01        0.97         0.61
# ...    ...         ...          ...
# 528   1.00        0.00         0.00
# 125   1.00        0.00         0.20
# 16    1.00        0.00         0.11
# 524   1.08        0.29         0.47
# 1644  3.25        0.14         0.20
#
#                                   parametres_traitement
# 963   -resize 200% -colorspace Gray -normalize -back...
# 7     -resize 200% -colorspace Gray -normalize -back...
# 82    -resize 200% -colorspace Gray -normalize -shar...
# 1389  -resize 200% -colorspace Gray -normalize -back...
# 976   -resize 200% -colorspace Gray -normalize -back...
# ...                                                 ...
# 528   -resize 200% -colorspace Gray -normalize -back...
# 125   -resize 200% -colorspace Gray -normalize -back...
# 16    -resize 200% -colorspace Gray -normalize -back...
# 524   -resize 200% -colorspace Gray -normalize -auto...
# 1644  -resize 200% -colorspace Gray -normalize -auto...
#
# [138 rows x 6 columns]

# %%
# 4. Afficher la variante la plus performante pour chaque page selon le score global
idx_best_global = df.groupby('fichier')['cer'].idxmin()
df.loc[idx_best_global].sort_values('cer', ascending=False)
# Out:
#                                                 fichier                   cat  \
# 1644  ce14a9e93aadabb89005c15a8b594e617f7f1bf1b507cb...               patents
# 524   b9884c5e29975ef8ce92f758b8fccbcfba1df6ab463848...     financial_reports
# 18    2371c0c368275bfd933d16d62a3c553965cc76c918d2c5...   scientific_articles
# 125   54136c909661ea088d7c825d90289eef65546501748894...  laws_and_regulations
# 16    c89de3e108a8ff86a04af6d817978d037daab718a66d5d...     financial_reports
# ...                                                 ...                   ...
# 976   7672298edc56d3ce972d879f345e70331b103a9f8ac6c4...               manuals
# 578   f8908cb30bff20e344e872f1834ed40c03ba2f77f45aa0...               manuals
# 41    e41f7bf4b17794c3b4c9190057edec1e9c560e67fe482e...     financial_reports
# 641   fc16c317ff91df369c23dfa2f926a2ff70c5fcc800990d...               manuals
# 963   4d9297edf17763150c04fb2b49a4b28791cba63b1d1189...  laws_and_regulations
#
#        cer  jacc_multi  ratios_mean  \
# 1644  3.25        0.14         0.20
# 524   1.08        0.29         0.47
# 18    1.00        0.00         0.00
# 125   1.00        0.00         0.20
# 16    1.00        0.00         0.11
# ...    ...         ...          ...
# 976   0.01        0.97         0.61
# 578   0.01        0.91         0.42
# 41    0.01        1.00         0.67
# 641   0.01        0.98         0.42
# 963   0.00        1.00         0.60
#
#                                   parametres_traitement
# 1644  -resize 200% -colorspace Gray -normalize -auto...
# 524   -resize 200% -colorspace Gray -normalize -auto...
# 18    -resize 200% -colorspace Gray -normalize -back...
# 125   -resize 200% -colorspace Gray -normalize -back...
# 16    -resize 200% -colorspace Gray -normalize -back...
# ...                                                 ...
# 976   -resize 200% -colorspace Gray -normalize -back...
# 578   -resize 200% -colorspace Gray -normalize -auto...
# 41    -resize 200% -colorspace Gray -auto-level -sha...
# 641   -resize 200% -colorspace Gray -normalize -back...
# 963   -resize 200% -colorspace Gray -normalize -back...
#
# [138 rows x 6 columns]

# %%
# 8. Comparer les scores moyens par méthode
df.groupby('parametres_traitement')[['cer']].mean().sort_values('cer', ascending=False)
# Out:
#                                                          cer
# parametres_traitement
# -resize 200% -colorspace Gray -auto-level -shar...  0.903364
# -resize 200% -colorspace Gray -normalize -adapt...  0.856863
# -resize 200% -colorspace Gray -normalize -sharp...  0.827130
# -resize 200% -colorspace Gray -normalize -auto-...  0.811619
# -resize 200% -colorspace Gray -normalize -enhance   0.771622
# -resize 200% -colorspace Gray -contrast-stretch...  0.759590
# -resize 200% -colorspace Gray -white-threshold ...  0.753717
# -resize 200% -colorspace Gray -blur 1x1 -auto-t...  0.747103
# -resize 200% -colorspace Gray -normalize -backg...  0.737246
# -resize 200% -colorspace Gray -deskew 40% -norm...  0.726783
# -resize 200% -colorspace Gray -normalize -sharp...  0.703228
# -resize 200% -colorspace Gray -auto-level -norm...  0.700707
# -resize 200% -colorspace Gray -normalize -deske...  0.687980
# -resize 200% -colorspace Gray -auto-gamma -auto...  0.676827
# -resize 200% -colorspace Gray -normalize -auto-...  0.669708
# -resize 200% -colorspace Gray -median 3 -normalize  0.663551

# %%
# 3. Analyse des “meilleures variantes” pour chaque document
df['cer'] = df['cer'].fillna(1)
best_by_doc = df.loc[df.groupby('fichier')['cer'].idxmin()]
best_counts = best_by_doc['parametres_traitement'].value_counts()
print(best_counts)
# Out:
# parametres_traitement
# -resize 200% -colorspace Gray -normalize -background white -flatten                      51
# -resize 200% -colorspace Gray -normalize -auto-threshold Triangle                        15
# -resize 200% -colorspace Gray -auto-gamma -auto-threshold Otsu                           13
# -resize 200% -colorspace Gray -auto-level -sharpen 0x1                                   12
# -resize 200% -colorspace Gray -normalize -sharpen 0x1 -auto-threshold Otsu               10
# -resize 200% -colorspace Gray -normalize -auto-threshold Otsu                             6
# -resize 200% -colorspace Gray -median 3 -normalize                                        6
# -resize 200% -colorspace Gray -blur 1x1 -auto-threshold Otsu                              5
# -resize 200% -colorspace Gray -normalize -sharpen 0x2 -despeckle -auto-threshold Otsu     5
# -resize 200% -colorspace Gray -contrast-stretch 0.3%x0.3% -auto-threshold Otsu            5
# -resize 200% -colorspace Gray -normalize -enhance                                         3
# -resize 200% -colorspace Gray -deskew 40% -normalize -auto-threshold Otsu                 2
# -resize 200% -colorspace Gray -auto-level -normalize -auto-threshold Otsu                 2
# -resize 200% -colorspace Gray -white-threshold 80% -normalize -auto-threshold Otsu        2
# -resize 200% -colorspace Gray -normalize -adaptive-sharpen 0x2 -auto-threshold Otsu       1
# Name: count, dtype: int64

# %%
# 1. Tableau croisé (pivot table) : document x variante
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Pivot table : index=fichier, columns=variante, values=cer
pivot = df.pivot(index="fichier", columns="parametres_traitement", values="cer")

plt.figure(figsize=(16, 8))
sns.heatmap(pivot, cmap="viridis", vmax=1)  # vmax limite l'affichage
plt.title("Matrice CER - Fichiers vs Variantes")
plt.show()

# %%
# 2. Clustering/Grouping des résultats
from sklearn.cluster import KMeans

X = pivot.fillna(1).values  # remplace les NaN (cas non testé) par un score mauvais
kmeans = KMeans(n_clusters=3, random_state=0).fit(X)
df_clusters = pd.DataFrame({'fichier': pivot.index, 'cluster': kmeans.labels_})
pivot['cluster'] = kmeans.labels_

# Visualiser les profils
pivot_sorted = pivot.sort_values('cluster')
sns.heatmap(pivot_sorted.iloc[:,:-1], cmap="viridis", vmax=1)
plt.title("Matrice CER triée par cluster de documents")
plt.show()

# %%
# 8. Comparer les scores moyens par méthode
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Récupère l’ordre des clusters
row_colors = pivot_sorted['cluster'].map({0: 'red', 1: 'green', 2: 'blue',})

sns.clustermap(
    pivot_sorted.iloc[:, :-1],  # retire la colonne 'cluster'
    row_colors=row_colors,
    figsize=(12, 10),
    cmap='viridis',
    vmin=0, vmax=1
)
plt.title("CER par cluster (couleurs = cluster)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[103], line 9
#       6 # Récupère l’ordre des clusters
#       7 row_colors = pivot_sorted['cluster'].map({0: 'red', 1: 'green', 2: 'blue',})
# ----> 9 sns.clustermap(
#      10     pivot_sorted.iloc[:, :-1],  # retire la colonne 'cluster'
#      11     row_colors=row_colors,
#      12     figsize=(12, 10),
#      13     cmap='viridis',
#      14     vmin=0, vmax=1
#      15 )
#      16 plt.title("CER par cluster (couleurs = cluster)")
#      17 plt.show()
#
# File ~\dev\env\Lib\site-packages\seaborn\matrix.py:1258, in clustermap(data, pivot_kws, method, metric, z_score, standard_scale, figsize, cbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, row_colors, col_colors, mask, dendrogram_ratio, colors_ratio, cbar_pos, tree_kws, **kwargs)
#    1250     raise RuntimeError("clustermap requires scipy to be available")
#    1252 plotter = ClusterGrid(data, pivot_kws=pivot_kws, figsize=figsize,
#    1253                       row_colors=row_colors, col_colors=col_colors,
#    1254                       z_score=z_score, standard_scale=standard_scale,
#    1255                       mask=mask, dendrogram_ratio=dendrogram_ratio,
#    1256                       colors_ratio=colors_ratio, cbar_pos=cbar_pos)
# -> 1258 return plotter.plot(metric=metric, method=method,
#    1259                     colorbar_kws=cbar_kws,
#    1260                     row_cluster=row_cluster, col_cluster=col_cluster,
#    1261                     row_linkage=row_linkage, col_linkage=col_linkage,
#    1262                     tree_kws=tree_kws, **kwargs)
#
# File ~\dev\env\Lib\site-packages\seaborn\matrix.py:1129, in ClusterGrid.plot(self, metric, method, colorbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, tree_kws, **kws)
#    1125     kws.pop("square")
#    1127 colorbar_kws = {} if colorbar_kws is None else colorbar_kws
# -> 1129 self.plot_dendrograms(row_cluster, col_cluster, metric, method,
#    1130                       row_linkage=row_linkage, col_linkage=col_linkage,
#    1131                       tree_kws=tree_kws)
#    1132 try:
#    1133     xind = self.dendrogram_col.reordered_ind
#
# File ~\dev\env\Lib\site-packages\seaborn\matrix.py:974, in ClusterGrid.plot_dendrograms(self, row_cluster, col_cluster, metric, method, row_linkage, col_linkage, tree_kws)
#     970 def plot_dendrograms(self, row_cluster, col_cluster, metric, method,
#     971                      row_linkage, col_linkage, tree_kws):
#     972     # Plot the row dendrogram
#     973     if row_cluster:
# --> 974         self.dendrogram_row = dendrogram(
#     975             self.data2d, metric=metric, method=method, label=False, axis=0,
#     976             ax=self.ax_row_dendrogram, rotate=True, linkage=row_linkage,
#     977             tree_kws=tree_kws
#     978         )
#     979     else:
#     980         self.ax_row_dendrogram.set_xticks([])
#
# File ~\dev\env\Lib\site-packages\seaborn\matrix.py:687, in dendrogram(data, linkage, axis, label, metric, method, rotate, tree_kws, ax)
#     684 if _no_scipy:
#     685     raise RuntimeError("dendrogram requires scipy to be installed")
# --> 687 plotter = _DendrogramPlotter(data, linkage=linkage, axis=axis,
#     688                              metric=metric, method=method,
#     689                              label=label, rotate=rotate)
#     690 if ax is None:
#     691     ax = plt.gca()
#
# File ~\dev\env\Lib\site-packages\seaborn\matrix.py:495, in _DendrogramPlotter.__init__(self, data, linkage, metric, method, axis, label, rotate)
#     492 self.rotate = rotate
#     494 if linkage is None:
# --> 495     self.linkage = self.calculated_linkage
#     496 else:
#     497     self.linkage = linkage
#
# File ~\dev\env\Lib\site-packages\seaborn\matrix.py:562, in _DendrogramPlotter.calculated_linkage(self)
#     558         msg = ("Clustering large matrix with scipy. Installing "
#     559                "`fastcluster` may give better performance.")
#     560         warnings.warn(msg)
# --> 562 return self._calculate_linkage_scipy()
#
# File ~\dev\env\Lib\site-packages\seaborn\matrix.py:530, in _DendrogramPlotter._calculate_linkage_scipy(self)
#     529 def _calculate_linkage_scipy(self):
# --> 530     linkage = hierarchy.linkage(self.array, method=self.method,
#     531                                 metric=self.metric)
#     532     return linkage
#
# File ~\dev\env\Lib\site-packages\scipy\cluster\hierarchy.py:1030, in linkage(y, method, metric, optimal_ordering)
#    1027     raise ValueError("`y` must be 1 or 2 dimensional.")
#    1029 if not xp.all(xp.isfinite(y)):
# -> 1030     raise ValueError("The condensed distance matrix must contain only "
#    1031                      "finite values.")
#    1033 n = int(distance.num_obs_y(y))
#    1034 method_code = _LINKAGE_METHODS[method]
#
# ValueError: The condensed distance matrix must contain only finite values.

# %%
# 8. Comparer les scores moyens par méthode
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

# On ne garde que les colonnes intéressantes
vars_clustering = ["cer", "jacc_multi", "ratios_mean", "parametres_traitement", "fichier"]
df = df[vars_clustering].dropna()

# Optionnel : standardise les variables (important pour le clustering)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df[["cer", "jacc_multi", "ratios_mean"]])

# Clustering
kmeans = KMeans(n_clusters=3, random_state=0)
df["cluster"] = kmeans.fit_predict(X_scaled)

print(df.groupby("parametres_traitement")["cluster"].value_counts())
# Out:
# parametres_traitement                                                                  cluster
# -resize 200% -colorspace Gray -auto-gamma -auto-threshold Otsu                         0           70
#                                                                                        1           33
#                                                                                        2            1
# -resize 200% -colorspace Gray -auto-level -normalize -auto-threshold Otsu              0           75
#                                                                                        1           23
#                                                                                        2            1
# -resize 200% -colorspace Gray -auto-level -sharpen 0x1                                 0           71
#                                                                                        1           37
#                                                                                        2            2
# -resize 200% -colorspace Gray -blur 1x1 -auto-threshold Otsu                           0           71
#                                                                                        1           35
#                                                                                        2            1
# -resize 200% -colorspace Gray -contrast-stretch 0.3%x0.3% -auto-threshold Otsu         0           84
#                                                                                        1           37
#                                                                                        2            1
# -resize 200% -colorspace Gray -deskew 40% -normalize -auto-threshold Otsu              0           75
#                                                                                        1           39
#                                                                                        2            1
# -resize 200% -colorspace Gray -median 3 -normalize                                     0           77
#                                                                                        1           29
#                                                                                        2            1
# -resize 200% -colorspace Gray -normalize -adaptive-sharpen 0x2 -auto-threshold Otsu    0           72
#                                                                                        1           29
#                                                                                        2            1
# -resize 200% -colorspace Gray -normalize -auto-threshold Otsu                          0           99
#                                                                                        1           37
#                                                                                        2            1
# -resize 200% -colorspace Gray -normalize -auto-threshold Triangle                      1           53
#                                                                                        0           51
#                                                                                        2            1
# -resize 200% -colorspace Gray -normalize -background white -flatten                    0          102
#                                                                                        1           35
#                                                                                        2            1
# -resize 200% -colorspace Gray -normalize -deskew 40% -auto-threshold Otsu              0           74
#                                                                                        1           24
#                                                                                        2            1
# -resize 200% -colorspace Gray -normalize -enhance                                      0           75
#                                                                                        1           35
#                                                                                        2            1
# -resize 200% -colorspace Gray -normalize -sharpen 0x1 -auto-threshold Otsu             0           93
#                                                                                        1           33
#                                                                                        2            1
# -resize 200% -colorspace Gray -normalize -sharpen 0x2 -despeckle -auto-threshold Otsu  0           77
#                                                                                        1           37
#                                                                                        2            1
# -resize 200% -colorspace Gray -white-threshold 80% -normalize -auto-threshold Otsu     0           79
#                                                                                        1           33
#                                                                                        2            1
# Name: count, dtype: int64

# %%
# 8. Comparer les scores moyens par méthode
sns.pairplot(df, vars=["cer", "jacc_multi", "ratios_mean"], hue="cluster")
plt.suptitle("Clustering des documents selon 3 variables", y=1.02)
plt.show()

# %%
plt.figure(figsize=(12,4))
sns.boxplot(x="parametres_traitement", y="cer", hue="cluster", data=df)
plt.xticks(rotation=90)
plt.title("Distribution du CER par variante et par cluster")
plt.show()

# %%
print(df.groupby("cluster")[["cer", "jacc_multi", "ratios_mean"]].mean())
# Out:
#                cer  jacc_multi  ratios_mean
# cluster
# 0         0.301695    0.786217     0.532129
# 1         1.123862    0.106885     0.172149
# 2        21.363529    0.023529     0.060000

# %%
import pandas as pd

# Suppose df contient : fichier, cer, jacc_multi, ratios_mean, parametres_traitement

# Pour chaque doc, la variante à meilleur cer
idx_cer = df.groupby("fichier")["cer"].idxmin()
df_best_cer = df.loc[idx_cer, ["fichier", "parametres_traitement", "cer"]].rename(columns={"parametres_traitement": "best_cer_variante", "cer":"best_cer"})

# Pareil pour jacc_multi (max au lieu de min)
idx_jacc = df.groupby("fichier")["jacc_multi"].idxmax()
df_best_jacc = df.loc[idx_jacc, ["fichier", "parametres_traitement", "jacc_multi"]].rename(columns={"parametres_traitement": "best_jacc_variante", "jacc_multi":"best_jacc"})

# Et ratios_mean (selon ce que tu veux : plus proche de 1 ou max ? Ici max)
idx_ratios = df.groupby("fichier")["ratios_mean"].idxmax()
df_best_ratios = df.loc[idx_ratios, ["fichier", "parametres_traitement", "ratios_mean"]].rename(columns={"parametres_traitement": "best_ratios_variante", "ratios_mean":"best_ratios"})

# Fusionne tout
df_best = df_best_cer.merge(df_best_jacc, on="fichier").merge(df_best_ratios, on="fichier")

# %%
# Regroupement par triplet de variantes gagnantes
df_best["profil"] = df_best[["best_cer_variante", "best_jacc_variante", "best_ratios_variante"]].agg("_".join, axis=1)
profils = df_best["profil"].value_counts()
print("Répartition des profils de variantes gagnantes :")
print(profils)
# Out:
# Répartition des profils de variantes gagnantes :
# profil
# -resize 200% -colorspace Gray -normalize -background white -flatten_-resize 200% -colorspace Gray -normalize -background white -flatten_-resize 200% -colorspace Gray -normalize -background white -flatten      29
# -resize 200% -colorspace Gray -auto-level -sharpen 0x1_-resize 200% -colorspace Gray -auto-level -sharpen 0x1_-resize 200% -colorspace Gray -auto-level -sharpen 0x1                                              4
# -resize 200% -colorspace Gray -normalize -background white -flatten_-resize 200% -colorspace Gray -normalize -background white -flatten_-resize 200% -colorspace Gray -normalize -auto-threshold Otsu             4
# -resize 200% -colorspace Gray -auto-level -sharpen 0x1_-resize 200% -colorspace Gray -normalize -background white -flatten_-resize 200% -colorspace Gray -normalize -background white -flatten                    3
# -resize 200% -colorspace Gray -normalize -auto-threshold Triangle_-resize 200% -colorspace Gray -normalize -auto-threshold Triangle_-resize 200% -colorspace Gray -normalize -auto-threshold Triangle             3
#                                                                                                                                                                                                                  ..
# -resize 200% -colorspace Gray -normalize -auto-threshold Triangle_-resize 200% -colorspace Gray -auto-level -normalize -auto-threshold Otsu_-resize 200% -colorspace Gray -normalize -enhance                     1
# -resize 200% -colorspace Gray -normalize -auto-threshold Otsu_-resize 200% -colorspace Gray -median 3 -normalize_-resize 200% -colorspace Gray -normalize -auto-threshold Otsu                                    1
# -resize 200% -colorspace Gray -auto-gamma -auto-threshold Otsu_-resize 200% -colorspace Gray -normalize -background white -flatten_-resize 200% -colorspace Gray -normalize -sharpen 0x1 -auto-threshold Otsu     1
# -resize 200% -colorspace Gray -auto-gamma -auto-threshold Otsu_-resize 200% -colorspace Gray -auto-level -sharpen 0x1_-resize 200% -colorspace Gray -normalize -sharpen 0x1 -auto-threshold Otsu                  1
# -resize 200% -colorspace Gray -normalize -background white -flatten_-resize 200% -colorspace Gray -normalize -auto-threshold Otsu_-resize 200% -colorspace Gray -normalize -background white -flatten             1
# Name: count, Length: 86, dtype: int64

# %%
import pandas as pd

# On suppose que df contient : fichier, cer, jacc_multi, ratios_mean, parametres_traitement

# --- Trouver la meilleure variante pour chaque document par critère ---

# Pour CER (le plus petit)
best_cer_idx = df.groupby("fichier")["cer"].idxmin()
best_cer_variantes = df.loc[best_cer_idx, "parametres_traitement"]

# Pour Jaccard multi (le plus grand)
best_jacc_idx = df.groupby("fichier")["jacc_multi"].idxmax()
best_jacc_variantes = df.loc[best_jacc_idx, "parametres_traitement"]

# Pour Ratios_mean (le plus grand, sauf si tu veux autre chose)
best_ratios_idx = df.groupby("fichier")["ratios_mean"].apply(lambda x: (x-1).abs().idxmin())
best_ratios_variantes = df.loc[best_ratios_idx, "parametres_traitement"]

# --- Compter la fréquence de chaque variante gagnante ---
classement_cer = best_cer_variantes.value_counts()
classement_jacc = best_jacc_variantes.value_counts()
classement_ratios = best_ratios_variantes.value_counts()

print("Classement des variantes (nb de fois meilleures sur CER):")
print(classement_cer)
print("\nClassement des variantes (nb de fois meilleures sur Jaccard):")
print(classement_jacc)
print("\nClassement des variantes (nb de fois meilleures sur Ratios_mean):")
print(classement_ratios)

classement_df = pd.DataFrame({
    "best_cer": classement_cer,
    "best_jacc": classement_jacc,
    "best_ratios": classement_ratios
}).fillna(0).astype(int).sort_values("best_cer", ascending=False)
print(classement_df)
# Out:
# Classement des variantes (nb de fois meilleures sur CER):
# parametres_traitement
# -resize 200% -colorspace Gray -normalize -background white -flatten                      51
# -resize 200% -colorspace Gray -normalize -auto-threshold Triangle                        15
# -resize 200% -colorspace Gray -auto-gamma -auto-threshold Otsu                           13
# -resize 200% -colorspace Gray -auto-level -sharpen 0x1                                   12
# -resize 200% -colorspace Gray -normalize -sharpen 0x1 -auto-threshold Otsu               10
# -resize 200% -colorspace Gray -normalize -auto-threshold Otsu                             6
# -resize 200% -colorspace Gray -median 3 -normalize                                        6
# -resize 200% -colorspace Gray -blur 1x1 -auto-threshold Otsu                              5
# -resize 200% -colorspace Gray -normalize -sharpen 0x2 -despeckle -auto-threshold Otsu     5
# -resize 200% -colorspace Gray -contrast-stretch 0.3%x0.3% -auto-threshold Otsu            5
# -resize 200% -colorspace Gray -normalize -enhance                                         3
# -resize 200% -colorspace Gray -deskew 40% -normalize -auto-threshold Otsu                 2
# -resize 200% -colorspace Gray -auto-level -normalize -auto-threshold Otsu                 2
# -resize 200% -colorspace Gray -white-threshold 80% -normalize -auto-threshold Otsu        2
# -resize 200% -colorspace Gray -normalize -adaptive-sharpen 0x2 -auto-threshold Otsu       1
# Name: count, dtype: int64
#
# Classement des variantes (nb de fois meilleures sur Jaccard):
# parametres_traitement
# -resize 200% -colorspace Gray -normalize -background white -flatten                      68
# -resize 200% -colorspace Gray -auto-level -sharpen 0x1                                   17
# -resize 200% -colorspace Gray -median 3 -normalize                                       14
# -resize 200% -colorspace Gray -normalize -enhance                                        12
# -resize 200% -colorspace Gray -normalize -sharpen 0x2 -despeckle -auto-threshold Otsu     4
# -resize 200% -colorspace Gray -auto-level -normalize -auto-threshold Otsu                 3
# -resize 200% -colorspace Gray -normalize -sharpen 0x1 -auto-threshold Otsu                3
# -resize 200% -colorspace Gray -normalize -auto-threshold Triangle                         3
# -resize 200% -colorspace Gray -normalize -auto-threshold Otsu                             3
# -resize 200% -colorspace Gray -auto-gamma -auto-threshold Otsu                            3
# -resize 200% -colorspace Gray -contrast-stretch 0.3%x0.3% -auto-threshold Otsu            2
# -resize 200% -colorspace Gray -deskew 40% -normalize -auto-threshold Otsu                 2
# -resize 200% -colorspace Gray -blur 1x1 -auto-threshold Otsu                              2
# -resize 200% -colorspace Gray -white-threshold 80% -normalize -auto-threshold Otsu        1
# -resize 200% -colorspace Gray -normalize -adaptive-sharpen 0x2 -auto-threshold Otsu       1
# Name: count, dtype: int64
#
# Classement des variantes (nb de fois meilleures sur Ratios_mean):
# parametres_traitement
# -resize 200% -colorspace Gray -normalize -background white -flatten                      51
# -resize 200% -colorspace Gray -auto-level -sharpen 0x1                                   11
# -resize 200% -colorspace Gray -normalize -auto-threshold Triangle                        11
# -resize 200% -colorspace Gray -auto-gamma -auto-threshold Otsu                            9
# -resize 200% -colorspace Gray -median 3 -normalize                                        9
# -resize 200% -colorspace Gray -normalize -sharpen 0x1 -auto-threshold Otsu                9
# -resize 200% -colorspace Gray -normalize -enhance                                         8
# -resize 200% -colorspace Gray -normalize -auto-threshold Otsu                             8
# -resize 200% -colorspace Gray -normalize -sharpen 0x2 -despeckle -auto-threshold Otsu     6
# -resize 200% -colorspace Gray -contrast-stretch 0.3%x0.3% -auto-threshold Otsu            5
# -resize 200% -colorspace Gray -blur 1x1 -auto-threshold Otsu                              3
# -resize 200% -colorspace Gray -auto-level -normalize -auto-threshold Otsu                 2
# -resize 200% -colorspace Gray -normalize -adaptive-sharpen 0x2 -auto-threshold Otsu       2
# -resize 200% -colorspace Gray -deskew 40% -normalize -auto-threshold Otsu                 2
# -resize 200% -colorspace Gray -white-threshold 80% -normalize -auto-threshold Otsu        1
# -resize 200% -colorspace Gray -normalize -deskew 40% -auto-threshold Otsu                 1
# Name: count, dtype: int64
#                                                     best_cer  best_jacc  \
# parametres_traitement
# -resize 200% -colorspace Gray -normalize -backg...        51         68
# -resize 200% -colorspace Gray -normalize -auto-...        15          3
# -resize 200% -colorspace Gray -auto-gamma -auto...        13          3
# -resize 200% -colorspace Gray -auto-level -shar...        12         17
# -resize 200% -colorspace Gray -normalize -sharp...        10          3
# -resize 200% -colorspace Gray -normalize -auto-...         6          3
# -resize 200% -colorspace Gray -median 3 -normalize         6         14
# -resize 200% -colorspace Gray -blur 1x1 -auto-t...         5          2
# -resize 200% -colorspace Gray -normalize -sharp...         5          4
# -resize 200% -colorspace Gray -contrast-stretch...         5          2
# -resize 200% -colorspace Gray -normalize -enhance          3         12
# -resize 200% -colorspace Gray -auto-level -norm...         2          3
# -resize 200% -colorspace Gray -white-threshold ...         2          1
# -resize 200% -colorspace Gray -deskew 40% -norm...         2          2
# -resize 200% -colorspace Gray -normalize -adapt...         1          1
# -resize 200% -colorspace Gray -normalize -deske...         0          0
#
#                                                     best_ratios
# parametres_traitement
# -resize 200% -colorspace Gray -normalize -backg...           51
# -resize 200% -colorspace Gray -normalize -auto-...           11
# -resize 200% -colorspace Gray -auto-gamma -auto...            9
# -resize 200% -colorspace Gray -auto-level -shar...           11
# -resize 200% -colorspace Gray -normalize -sharp...            9
# -resize 200% -colorspace Gray -normalize -auto-...            8
# -resize 200% -colorspace Gray -median 3 -normalize            9
# -resize 200% -colorspace Gray -blur 1x1 -auto-t...            3
# -resize 200% -colorspace Gray -normalize -sharp...            6
# -resize 200% -colorspace Gray -contrast-stretch...            5
# -resize 200% -colorspace Gray -normalize -enhance             8
# -resize 200% -colorspace Gray -auto-level -norm...            2
# -resize 200% -colorspace Gray -white-threshold ...            1
# -resize 200% -colorspace Gray -deskew 40% -norm...            2
# -resize 200% -colorspace Gray -normalize -adapt...            2
# -resize 200% -colorspace Gray -normalize -deske...            1

# %%
import matplotlib.pyplot as plt
classement_df.plot.bar(figsize=(12,6))
plt.title("Nombre de fois où chaque variante est la meilleure (par critère)")
plt.ylabel("Nombre de documents")
plt.xlabel("Variante de prétraitement")
plt.show()

# %%
import pandas as pd

# 2. Binariser le succès (ajuste les seuils si besoin)
df['succès'] = (df['cer'] < 0.08) | (df['jacc_multi'] > 0.92) | ((df['ratios_mean'] > 0.9) & (df['ratios_mean'] < 1.1))

# 3. Construire la matrice doc/variante
pivot = df.pivot_table(index='fichier', columns='parametres_traitement', values='succès', fill_value=0)

# 4. Initialisation
covered = set()
chosen_variants = []

# 5. Glouton : tant qu'il reste des documents non couverts…
while len(covered) < len(pivot):
    # Compter les docs nouvellement couverts par chaque variante
    best_variant = None
    best_gain = 0
    for v in pivot.columns:
        docs_covered = set(pivot.index[pivot[v]==1])
        gain = len(docs_covered - covered)
        if gain > best_gain:
            best_gain = gain
            best_variant = v
    if best_variant is None or best_gain == 0:
        break  # plus rien à gagner
    # Ajouter variante et marquer les docs couverts
    chosen_variants.append(best_variant)
    covered.update(pivot.index[pivot[best_variant]==1])
    print(f"Ajoutée : {best_variant} (couvre {best_gain} docs de plus, total couverts : {len(covered)})")

print("\nVariants choisis (ordre optimal glouton) :")
for i, v in enumerate(chosen_variants, 1):
    print(f"{i}. {v}")

print(f"\nCouvre {len(covered)}/{len(pivot)} documents ({100*len(covered)/len(pivot):.1f} %)")
# Out:
# Ajoutée : -resize 200% -colorspace Gray -normalize -background white -flatten (couvre 47 docs de plus, total couverts : 47)
# Ajoutée : -resize 200% -colorspace Gray -auto-level -normalize -auto-threshold Otsu (couvre 6 docs de plus, total couverts : 53)
# Ajoutée : -resize 200% -colorspace Gray -auto-level -sharpen 0x1 (couvre 3 docs de plus, total couverts : 56)
# Ajoutée : -resize 200% -colorspace Gray -auto-gamma -auto-threshold Otsu (couvre 1 docs de plus, total couverts : 57)
# Ajoutée : -resize 200% -colorspace Gray -median 3 -normalize (couvre 1 docs de plus, total couverts : 58)
#
# Variants choisis (ordre optimal glouton) :
# 1. -resize 200% -colorspace Gray -normalize -background white -flatten
# 2. -resize 200% -colorspace Gray -auto-level -normalize -auto-threshold Otsu
# 3. -resize 200% -colorspace Gray -auto-level -sharpen 0x1
# 4. -resize 200% -colorspace Gray -auto-gamma -auto-threshold Otsu
# 5. -resize 200% -colorspace Gray -median 3 -normalize
#
# Couvre 58/138 documents (42.0 %)

# %%
# 1️⃣ Trouver, pour chaque doc, la variante avec le meilleur CER (min) et le meilleur Jaccard (max)
idx_best_cer = df.groupby('fichier')['cer'].idxmin()
idx_best_jacc = df.groupby('fichier')['jacc_multi'].idxmax()

df_best_cer = df.loc[idx_best_cer, ['fichier', 'parametres_traitement', 'cer']]
df_best_jacc = df.loc[idx_best_jacc, ['fichier', 'parametres_traitement', 'jacc_multi']]

# 2️⃣ Afficher le classement des variantes (nb de fois meilleure)
print("\nClassement des variantes (nb de fois meilleures sur CER) :")
print(df_best_cer['parametres_traitement'].value_counts())
print("\nClassement des variantes (nb de fois meilleures sur Jaccard) :")
print(df_best_jacc['parametres_traitement'].value_counts())

# 3️⃣ Profils combinés CER/Jaccard
df_profils = pd.merge(
    df_best_cer[['fichier', 'parametres_traitement']].rename(columns={'parametres_traitement':'best_cer_variante'}),
    df_best_jacc[['fichier', 'parametres_traitement']].rename(columns={'parametres_traitement':'best_jacc_variante'}),
    on='fichier'
)

# On peut aussi ajouter la variante "ratios_mean" si tu veux (idem avec idxmax sur 'ratios_mean')
idx_best_ratios = df.groupby('fichier')['ratios_mean'].idxmax()
df_best_ratios = df.loc[idx_best_ratios, ['fichier', 'parametres_traitement']]
df_best_ratios = df_best_ratios.rename(columns={'parametres_traitement':'best_ratios_variante'})
df_profils = df_profils.merge(df_best_ratios, on='fichier')

# 4️⃣ Répartition des profils de variantes gagnantes (par couple gagnant)
df_profils['profil'] = df_profils[['best_cer_variante', 'best_jacc_variante']].agg('|'.join, axis=1)
print("\nRépartition des profils (meilleure variante CER + Jaccard) :")
print(df_profils['profil'].value_counts())

# 5️⃣ Facultatif : liste des documents par profil
for profil, subdf in df_profils.groupby('profil'):
    print(f"\nProfil {profil} : {len(subdf)} documents")
    print(subdf['fichier'].tolist())

# Pour aller plus loin : visualisation par heatmap, voir plus haut

# Tu peux aussi enregistrer les profils dans un CSV si besoin :
# df_profils.to_csv("profils_variantes_gagnantes.csv", index=False)
# Out:
# Classement des variantes (nb de fois meilleures sur CER) :
# parametres_traitement
# -resize 200% -colorspace Gray -normalize -background white -flatten                      51
# -resize 200% -colorspace Gray -normalize -auto-threshold Triangle                        15
# -resize 200% -colorspace Gray -auto-gamma -auto-threshold Otsu                           13
# -resize 200% -colorspace Gray -auto-level -sharpen 0x1                                   12
# -resize 200% -colorspace Gray -normalize -sharpen 0x1 -auto-threshold Otsu               10
# -resize 200% -colorspace Gray -normalize -auto-threshold Otsu                             6
# -resize 200% -colorspace Gray -median 3 -normalize                                        6
# -resize 200% -colorspace Gray -blur 1x1 -auto-threshold Otsu                              5
# -resize 200% -colorspace Gray -normalize -sharpen 0x2 -despeckle -auto-threshold Otsu     5
# -resize 200% -colorspace Gray -contrast-stretch 0.3%x0.3% -auto-threshold Otsu            5
# -resize 200% -colorspace Gray -normalize -enhance                                         3
# -resize 200% -colorspace Gray -deskew 40% -normalize -auto-threshold Otsu                 2
# -resize 200% -colorspace Gray -auto-level -normalize -auto-threshold Otsu                 2
# -resize 200% -colorspace Gray -white-threshold 80% -normalize -auto-threshold Otsu        2
# -resize 200% -colorspace Gray -normalize -adaptive-sharpen 0x2 -auto-threshold Otsu       1
# Name: count, dtype: int64
#
# Classement des variantes (nb de fois meilleures sur Jaccard) :
# parametres_traitement
# -resize 200% -colorspace Gray -normalize -background white -flatten                      68
# -resize 200% -colorspace Gray -auto-level -sharpen 0x1                                   17
# -resize 200% -colorspace Gray -median 3 -normalize                                       14
# -resize 200% -colorspace Gray -normalize -enhance                                        12
# -resize 200% -colorspace Gray -normalize -sharpen 0x2 -despeckle -auto-threshold Otsu     4
# -resize 200% -colorspace Gray -auto-level -normalize -auto-threshold Otsu                 3
# -resize 200% -colorspace Gray -normalize -sharpen 0x1 -auto-threshold Otsu                3
# -resize 200% -colorspace Gray -normalize -auto-threshold Triangle                         3
# -resize 200% -colorspace Gray -normalize -auto-threshold Otsu                             3
# -resize 200% -colorspace Gray -auto-gamma -auto-threshold Otsu                            3
# -resize 200% -colorspace Gray -contrast-stretch 0.3%x0.3% -auto-threshold Otsu            2
# -resize 200% -colorspace Gray -deskew 40% -normalize -auto-threshold Otsu                 2
# -resize 200% -colorspace Gray -blur 1x1 -auto-threshold Otsu                              2
# -resize 200% -colorspace Gray -white-threshold 80% -normalize -auto-threshold Otsu        1
# -resize 200% -colorspace Gray -normalize -adaptive-sharpen 0x2 -auto-threshold Otsu       1
# Name: count, dtype: int64
#
# Répartition des profils (meilleure variante CER + Jaccard) :
# profil
# -resize 200% -colorspace Gray -normalize -background white -flatten|-resize 200% -colorspace Gray -normalize -background white -flatten                                        41
# -resize 200% -colorspace Gray -normalize -background white -flatten|-resize 200% -colorspace Gray -auto-level -sharpen 0x1                                                      6
# -resize 200% -colorspace Gray -auto-level -sharpen 0x1|-resize 200% -colorspace Gray -auto-level -sharpen 0x1                                                                   6
# -resize 200% -colorspace Gray -auto-level -sharpen 0x1|-resize 200% -colorspace Gray -normalize -background white -flatten                                                      5
# -resize 200% -colorspace Gray -normalize -auto-threshold Triangle|-resize 200% -colorspace Gray -median 3 -normalize                                                            4
# -resize 200% -colorspace Gray -auto-gamma -auto-threshold Otsu|-resize 200% -colorspace Gray -normalize -background white -flatten                                              4
# -resize 200% -colorspace Gray -normalize -auto-threshold Triangle|-resize 200% -colorspace Gray -normalize -auto-threshold Triangle                                             3
# -resize 200% -colorspace Gray -normalize -sharpen 0x1 -auto-threshold Otsu|-resize 200% -colorspace Gray -normalize -sharpen 0x1 -auto-threshold Otsu                           3
# -resize 200% -colorspace Gray -blur 1x1 -auto-threshold Otsu|-resize 200% -colorspace Gray -normalize -background white -flatten                                                3
# -resize 200% -colorspace Gray -normalize -sharpen 0x1 -auto-threshold Otsu|-resize 200% -colorspace Gray -median 3 -normalize                                                   3
# -resize 200% -colorspace Gray -normalize -auto-threshold Triangle|-resize 200% -colorspace Gray -deskew 40% -normalize -auto-threshold Otsu                                     2
# -resize 200% -colorspace Gray -normalize -sharpen 0x2 -despeckle -auto-threshold Otsu|-resize 200% -colorspace Gray -normalize -sharpen 0x2 -despeckle -auto-threshold Otsu     2
# -resize 200% -colorspace Gray -normalize -auto-threshold Triangle|-resize 200% -colorspace Gray -normalize -background white -flatten                                           2
# -resize 200% -colorspace Gray -normalize -auto-threshold Triangle|-resize 200% -colorspace Gray -normalize -enhance                                                             2
# -resize 200% -colorspace Gray -auto-level -normalize -auto-threshold Otsu|-resize 200% -colorspace Gray -auto-level -normalize -auto-threshold Otsu                             2
# -resize 200% -colorspace Gray -contrast-stretch 0.3%x0.3% -auto-threshold Otsu|-resize 200% -colorspace Gray -normalize -background white -flatten                              2
# -resize 200% -colorspace Gray -normalize -sharpen 0x2 -despeckle -auto-threshold Otsu|-resize 200% -colorspace Gray -auto-level -sharpen 0x1                                    2
# -resize 200% -colorspace Gray -auto-gamma -auto-threshold Otsu|-resize 200% -colorspace Gray -normalize -enhance                                                                2
# -resize 200% -colorspace Gray -normalize -auto-threshold Otsu|-resize 200% -colorspace Gray -normalize -background white -flatten                                               2
# -resize 200% -colorspace Gray -normalize -background white -flatten|-resize 200% -colorspace Gray -median 3 -normalize                                                          2
# -resize 200% -colorspace Gray -median 3 -normalize|-resize 200% -colorspace Gray -normalize -background white -flatten                                                          2
# -resize 200% -colorspace Gray -median 3 -normalize|-resize 200% -colorspace Gray -median 3 -normalize                                                                           2
# -resize 200% -colorspace Gray -deskew 40% -normalize -auto-threshold Otsu|-resize 200% -colorspace Gray -normalize -background white -flatten                                   2
# -resize 200% -colorspace Gray -auto-gamma -auto-threshold Otsu|-resize 200% -colorspace Gray -median 3 -normalize                                                               2
# -resize 200% -colorspace Gray -normalize -auto-threshold Otsu|-resize 200% -colorspace Gray -normalize -auto-threshold Otsu                                                     2
# -resize 200% -colorspace Gray -blur 1x1 -auto-threshold Otsu|-resize 200% -colorspace Gray -blur 1x1 -auto-threshold Otsu                                                       2
# -resize 200% -colorspace Gray -white-threshold 80% -normalize -auto-threshold Otsu|-resize 200% -colorspace Gray -normalize -background white -flatten                          2
# -resize 200% -colorspace Gray -auto-gamma -auto-threshold Otsu|-resize 200% -colorspace Gray -auto-gamma -auto-threshold Otsu                                                   2
# -resize 200% -colorspace Gray -normalize -enhance|-resize 200% -colorspace Gray -normalize -background white -flatten                                                           2
# -resize 200% -colorspace Gray -auto-gamma -auto-threshold Otsu|-resize 200% -colorspace Gray -auto-level -sharpen 0x1                                                           2
# -resize 200% -colorspace Gray -normalize -adaptive-sharpen 0x2 -auto-threshold Otsu|-resize 200% -colorspace Gray -normalize -enhance                                           1
# -resize 200% -colorspace Gray -normalize -sharpen 0x1 -auto-threshold Otsu|-resize 200% -colorspace Gray -normalize -sharpen 0x2 -despeckle -auto-threshold Otsu                1
# -resize 200% -colorspace Gray -normalize -sharpen 0x1 -auto-threshold Otsu|-resize 200% -colorspace Gray -contrast-stretch 0.3%x0.3% -auto-threshold Otsu                       1
# -resize 200% -colorspace Gray -contrast-stretch 0.3%x0.3% -auto-threshold Otsu|-resize 200% -colorspace Gray -contrast-stretch 0.3%x0.3% -auto-threshold Otsu                   1
# -resize 200% -colorspace Gray -median 3 -normalize|-resize 200% -colorspace Gray -auto-level -sharpen 0x1                                                                       1
# -resize 200% -colorspace Gray -normalize -sharpen 0x1 -auto-threshold Otsu|-resize 200% -colorspace Gray -normalize -enhance                                                    1
# -resize 200% -colorspace Gray -contrast-stretch 0.3%x0.3% -auto-threshold Otsu|-resize 200% -colorspace Gray -normalize -sharpen 0x2 -despeckle -auto-threshold Otsu            1
# -resize 200% -colorspace Gray -normalize -sharpen 0x1 -auto-threshold Otsu|-resize 200% -colorspace Gray -normalize -background white -flatten                                  1
# -resize 200% -colorspace Gray -normalize -enhance|-resize 200% -colorspace Gray -normalize -enhance                                                                             1
# -resize 200% -colorspace Gray -auto-gamma -auto-threshold Otsu|-resize 200% -colorspace Gray -white-threshold 80% -normalize -auto-threshold Otsu                               1
# -resize 200% -colorspace Gray -normalize -auto-threshold Otsu|-resize 200% -colorspace Gray -normalize -enhance                                                                 1
# -resize 200% -colorspace Gray -normalize -sharpen 0x2 -despeckle -auto-threshold Otsu|-resize 200% -colorspace Gray -normalize -adaptive-sharpen 0x2 -auto-threshold Otsu       1
# -resize 200% -colorspace Gray -auto-level -sharpen 0x1|-resize 200% -colorspace Gray -normalize -enhance                                                                        1
# -resize 200% -colorspace Gray -median 3 -normalize|-resize 200% -colorspace Gray -normalize -enhance                                                                            1
# -resize 200% -colorspace Gray -normalize -background white -flatten|-resize 200% -colorspace Gray -normalize -enhance                                                           1
# -resize 200% -colorspace Gray -contrast-stretch 0.3%x0.3% -auto-threshold Otsu|-resize 200% -colorspace Gray -normalize -enhance                                                1
# -resize 200% -colorspace Gray -normalize -auto-threshold Triangle|-resize 200% -colorspace Gray -auto-gamma -auto-threshold Otsu                                                1
# -resize 200% -colorspace Gray -normalize -auto-threshold Triangle|-resize 200% -colorspace Gray -auto-level -normalize -auto-threshold Otsu                                     1
# -resize 200% -colorspace Gray -normalize -auto-threshold Otsu|-resize 200% -colorspace Gray -median 3 -normalize                                                                1
# -resize 200% -colorspace Gray -normalize -background white -flatten|-resize 200% -colorspace Gray -normalize -auto-threshold Otsu                                               1
# Name: count, dtype: int64
#
# Profil -resize 200% -colorspace Gray -auto-gamma -auto-threshold Otsu|-resize 200% -colorspace Gray -auto-gamma -auto-threshold Otsu : 2 documents
# ['819e80b5117a7894538861a9bafcf82df49d4a8e20fdfd729da0d6a4395369c5.txt', 'bacb95de7ecc4bcafb11d38efa38e38a7fc7b89e2830c7e757ccc5d81638486e.txt']
#
# Profil -resize 200% -colorspace Gray -auto-gamma -auto-threshold Otsu|-resize 200% -colorspace Gray -auto
-resize 200% -colorspace Gray -normalize -background white -flatten : 2 documents
# ['3e8773d021380216698a062cbe5d0687f3d8e66c74f9d789260f738a75e6c8df.txt', '9f0ed6776114ece54b2e2d3f2545d952c8d494eaa1f1d73c8839531b098c39dc.txt']
#
# Profil -resize 200% -colorspace Gray -normalize -enhance|-resize 200% -colorspace Gray -normalize -enhance : 1 documents
# ['5b7f25123c65dc4359949ba19c8a9397d04d6a08507daa96e5a219592ca654c3.txt']
#
# Profil -resize 200% -colorspace Gray -normalize -sharpen 0x1 -auto-threshold Otsu|-resize 200% -colorspace Gray -contrast-stretch 0.3%x0.3% -auto-threshold Otsu : 1 documents
# ['01b58f5f3a86262bd2a69db13eb46d5445951e506841b8c62c00164835933966.txt']
#
# Profil -resize 200% -colorspace Gray -normalize -sharpen 0x1 -auto-threshold Otsu|-resize 200% -colorspace Gray -median 3 -normalize : 3 documents
# ['38dcda0e37c4b5acc80f9952e97c213013154590f83b6171b638dfb35d96dfdf.txt', 'cebe3333e5a5788c8d4fc72881f85d507fb9f6a074af22c1d1a3a9bcae11286f.txt', 'e3ffb6d432da5cebd362bf7d68a59cee2267126a4602206df1c88bae3b7b916d.txt']
#
# Profil -resize 200% -colorspace Gray -normalize -sharpen 0x1 -auto-threshold Otsu|-resize 200% -colorspace Gray -normalize -background white -flatten : 1 documents
# ['6f0702986ae5135780dc58fd1f128b55d31a9a93efe52094de9cb3ff6b1ec25e.txt']
#
# Profil -resize 200% -colorspace Gray -normalize -sharpen 0x1 -auto-threshold Otsu|-resize 200% -colorspace Gray -normalize -enhance : 1 documents
# ['76a505343a34a40b2b4e17223032eda0f2e148f57fe809218648870ccdc3b9d3.txt']
#
# Profil -resize 200% -colorspace Gray -normalize -sharpen 0x1 -auto-threshold Otsu|-resize 200% -colorspace Gray -normalize -sharpen 0x1 -auto-threshold Otsu : 3 documents
# ['79b80a21307d31bbe705e30f62133a93b35687f9812a23b2636926a778f38d2b.txt', 'a391067f7ed762e0d19591c212a6ba7ca2da423cd8c41f5ad63aa357ec1de788.txt', 'f3005708ebbbbb576b03fdead0b51272ba5a0b32579efbd7a3958247fbd095b1.txt']
#
# Profil -resize 200% -colorspace Gray -normalize -sharpen 0x1 -auto-threshold Otsu|-resize 200% -colorspace Gray -normalize -sharpen 0x2 -despeckle -auto-threshold Otsu : 1 documents
# ['035af09291ce6f9735c60b6721f53e12fbd042c9a35cacf5ef460f6c0d2f2b03.txt']
#
# Profil -resize 200% -colorspace Gray -normalize -sharpen 0x2 -despeckle -auto-threshold Otsu|-resize 200% -colorspace Gray -auto-level -sharpen 0x1 : 2 documents
# ['07dac1a0af293f2f261c6e18642fed905190e1d4e11635606a22f55b0adb4c33.txt', '601febfd3972ff8015d3f121d6716a9b915533f309883a8591d8c2ced0e2c5b8.txt']
#
# Profil -resize 200% -colorspace Gray -normalize -sharpen 0x2 -despeckle -auto-threshold Otsu|-resize 200% -colorspace Gray -normalize -adaptive-sharpen 0x2 -auto-threshold Otsu : 1 documents
# ['8e245302aca66aff93e21d6bc07a2f1b7c267035310397d7f425a4832901d023.txt']
#
# Profil -resize 200% -colorspace Gray -normalize -sharpen 0x2 -despeckle -auto-threshold Otsu|-resize 200% -colorspace Gray -normalize -sharpen 0x2 -despeckle -auto-threshold Otsu : 2 documents
# ['298e6fbc7d55bbcdd052878e78309494caef2fbdcbb9f5a41c08dc8e1279f377.txt', '47377d46af156ccb720854f5c51df384be0385373ff8bd4f66be10364445cccc.txt']
#
# Profil -resize 200% -colorspace Gray -white-threshold 80% -normalize -auto-threshold Otsu|-resize 200% -colorspace Gray -normalize -background white -flatten : 2 documents
# ['971d129ee4137ff4a0af25323b206fbecbf2aab7fcbb81ffebcb5c9b21d2f59a.txt', 'b1c934fe4584e75b6098fabb380a4c6f1b5f389742c7bd214a900876b19c1263.txt']

# %%
grouped = df.groupby("parametres_traitement").agg(
    cer_mean = ("cer", "mean"),
    cer_std = ("cer", "std"),
    cer_med = ("cer", "median"),
    win_cer = ("cer", lambda x: (x == x.min()).sum()),
    jacc_mean = ("jacc_multi", "mean"),
    jacc_std = ("jacc_multi", "std"),
    jacc_med = ("jacc_multi", "median"),
    win_jacc = ("jacc_multi", lambda x: (x == x.max()).sum()),
    n_docs = ("fichier", "count")
).sort_values("cer_mean")

print(grouped)
# Out:
#                                                     cer_mean   cer_std  \
# parametres_traitement
# -resize 200% -colorspace Gray -median 3 -normalize  0.663551  1.820679
# -resize 200% -colorspace Gray -normalize -auto-...  0.669708  1.731369
# -resize 200% -colorspace Gray -auto-gamma -auto...  0.676827  1.563876
# -resize 200% -colorspace Gray -normalize -deske...  0.687980  1.807112
# -resize 200% -colorspace Gray -auto-level -norm...  0.700707  2.041884
# -resize 200% -colorspace Gray -normalize -sharp...  0.703228  2.080104
# -resize 200% -colorspace Gray -deskew 40% -norm...  0.726783  1.636342
# -resize 200% -colorspace Gray -normalize -backg...  0.737246  2.642803
# -resize 200% -colorspace Gray -blur 1x1 -auto-t...  0.747103  1.910061
# -resize 200% -colorspace Gray -white-threshold ...  0.753717  2.228894
# -resize 200% -colorspace Gray -contrast-stretch...  0.759590  2.375743
# -resize 200% -colorspace Gray -normalize -enhance   0.771622  2.152562
# -resize 200% -colorspace Gray -normalize -auto-...  0.811619  2.448220
# -resize 200% -colorspace Gray -normalize -sharp...  0.827130  2.416049
# -resize 200% -colorspace Gray -normalize -adapt...  0.856863  2.865440
# -resize 200% -colorspace Gray -auto-level -shar...  0.903364  2.879689
#
#                                                     cer_med  win_cer  \
# parametres_traitement
# -resize 200% -colorspace Gray -median 3 -normalize    0.380        1
# -resize 200% -colorspace Gray -normalize -auto-...    0.470        1
# -resize 200% -colorspace Gray -auto-gamma -auto...    0.490        2
# -resize 200% -colorspace Gray -normalize -deske...    0.350        1
# -resize 200% -colorspace Gray -auto-level -norm...    0.340        1
# -resize 200% -colorspace Gray -normalize -sharp...    0.420        1
# -resize 200% -colorspace Gray -deskew 40% -norm...    0.570        1
# -resize 200% -colorspace Gray -normalize -backg...    0.460        1
# -resize 200% -colorspace Gray -blur 1x1 -auto-t...    0.510        1
# -resize 200% -colorspace Gray -white-threshold ...    0.380        1
# -resize 200% -colorspace Gray -contrast-stretch...    0.440        1
# -resize 200% -colorspace Gray -normalize -enhance     0.510        1
# -resize 200% -colorspace Gray -normalize -auto-...    0.610        1
# -resize 200% -colorspace Gray -normalize -sharp...    0.560        1
# -resize 200% -colorspace Gray -normalize -adapt...    0.495        1
# -resize 200% -colorspace Gray -auto-level -shar...    0.540        1
#
#                                                     jacc_mean  jacc_std  \
# parametres_traitement
# -resize 200% -colorspace Gray -median 3 -normalize   0.643271  0.363073
# -resize 200% -colorspace Gray -normalize -auto-...   0.608613  0.344284
# -resize 200% -colorspace Gray -auto-gamma -auto...   0.481442  0.324413
# -resize 200% -colorspace Gray -normalize -deske...   0.622222  0.332472
# -resize 200% -colorspace Gray -auto-level -norm...   0.639495  0.333884
# -resize 200% -colorspace Gray -normalize -sharp...   0.597480  0.342813
# -resize 200% -colorspace Gray -deskew 40% -norm...   0.549565  0.359923
# -resize 200% -colorspace Gray -normalize -backg...   0.657609  0.356308
# -resize 200% -colorspace Gray -blur 1x1 -auto-t...   0.544579  0.347672
# -resize 200% -colorspace Gray -white-threshold ...   0.588761  0.352864
# -resize 200% -colorspace Gray -contrast-stretch...   0.588852  0.354247
# -resize 200% -colorspace Gray -normalize -enhance    0.611892  0.380434
# -resize 200% -colorspace Gray -normalize -auto-...   0.259429  0.200987
# -resize 200% -colorspace Gray -normalize -sharp...   0.559826  0.356297
# -resize 200% -colorspace Gray -normalize -adapt...   0.587353  0.355853
# -resize 200% -colorspace Gray -auto-level -shar...   0.589182  0.382054
#
#                                                     jacc_med  win_jacc  n_docs
# parametres_traitement
# -resize 200% -colorspace Gray -median 3 -normalize     0.820         4     107
# -resize 200% -colorspace Gray -normalize -auto-...     0.770         2     137
# -resize 200% -colorspace Gray -auto-gamma -auto...     0.515         1     104
# -resize 200% -colorspace Gray -normalize -deske...     0.770         1      99
# -resize 200% -colorspace Gray -auto-level -norm...     0.800         2      99
# -resize 200% -colorspace Gray -normalize -sharp...     0.770         2     127
# -resize 200% -colorspace Gray -deskew 40% -norm...     0.700         2     115
# -resize 200% -colorspace Gray -normalize -backg...     0.835         5     138
# -resize 200% -colorspace Gray -blur 1x1 -auto-t...     0.650         2     107
# -resize 200% -colorspace Gray -white-threshold ...     0.760         1     113
# -resize 200% -colorspace Gray -contrast-stretch...     0.760         2     122
# -resize 200% -colorspace Gray -normalize -enhance      0.830         4     111
# -resize 200% -colorspace Gray -normalize -auto-...     0.220         1     105
# -resize 200% -colorspace Gray -normalize -sharp...     0.710         3     115
# -resize 200% -colorspace Gray -normalize -adapt...     0.770         3     102
# -resize 200% -colorspace Gray -auto-level -shar...     0.780         4     110

# %%
# Pour chaque variante, combien de fois “best” ET quelle est sa moyenne de score (CER moyen, etc.)
res = df.groupby("parametres_traitement")["cer"].agg(["mean", "min", "max", "count"]).sort_values("mean")
print(res)
# Out:
#                                                         mean   min    max  \
# parametres_traitement
# -resize 200% -colorspace Gray -median 3 -normalize  0.663551  0.00  18.46
# -resize 200% -colorspace Gray -normalize -auto-...  0.669708  0.00  19.11
# -resize 200% -colorspace Gray -auto-gamma -auto...  0.676827  0.02  15.46
# -resize 200% -colorspace Gray -normalize -deske...  0.687980  0.00  16.66
# -resize 200% -colorspace Gray -auto-level -norm...  0.700707  0.00  19.26
# -resize 200% -colorspace Gray -normalize -sharp...  0.703228  0.00  21.91
# -resize 200% -colorspace Gray -deskew 40% -norm...  0.726783  0.00  16.03
# -resize 200% -colorspace Gray -normalize -backg...  0.737246  0.00  30.49
# -resize 200% -colorspace Gray -blur 1x1 -auto-t...  0.747103  0.00  19.11
# -resize 200% -colorspace Gray -white-threshold ...  0.753717  0.00  22.34
# -resize 200% -colorspace Gray -contrast-stretch...  0.759590  0.00  25.34
# -resize 200% -colorspace Gray -normalize -enhance   0.771622  0.00  21.51
# -resize 200% -colorspace Gray -normalize -auto-...  0.811619  0.05  25.34
# -resize 200% -colorspace Gray -normalize -sharp...  0.827130  0.00  24.23
# -resize 200% -colorspace Gray -normalize -adapt...  0.856863  0.00  27.51
# -resize 200% -colorspace Gray -auto-level -shar...  0.903364  0.00  28.09
#
#                                                     count
# parametres_traitement
# -resize 200% -colorspace Gray -median 3 -normalize    107
# -resize 200% -colorspace Gray -normalize -auto-...    137
# -resize 200% -colorspace Gray -auto-gamma -auto...    104
# -resize 200% -colorspace Gray -normalize -deske...     99
# -resize 200% -colorspace Gray -auto-level -norm...     99
# -resize 200% -colorspace Gray -normalize -sharp...    127
# -resize 200% -colorspace Gray -deskew 40% -norm...    115
# -resize 200% -colorspace Gray -normalize -backg...    138
# -resize 200% -colorspace Gray -blur 1x1 -auto-t...    107
# -resize 200% -colorspace Gray -white-threshold ...    113
# -resize 200% -colorspace Gray -contrast-stretch...    122
# -resize 200% -colorspace Gray -normalize -enhance     111
# -resize 200% -colorspace Gray -normalize -auto-...    105
# -resize 200% -colorspace Gray -normalize -sharp...    115
# -resize 200% -colorspace Gray -normalize -adapt...    102
# -resize 200% -colorspace Gray -auto-level -shar...    110
