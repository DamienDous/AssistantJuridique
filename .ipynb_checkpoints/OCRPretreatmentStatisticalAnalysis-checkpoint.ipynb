# %%
import pandas as pd

df = pd.read_csv("DB/reference/out/score_final.csv", header=None)
# Renomme les colonnes si besoin (adapte les noms à ton format réel !)
df.columns = [
    "fichier",
    "wer",
    "cer",
    "nb_mots_ref",
    "nb_mots_ocr",
    "ratio_mots",
    "nb_paragraphes_ref",
    "nb_paragraphes_ocr",
    "ratio_paragraphes",
    "nb_maj_ref",
    "nb_maj_ocr",
    "ratio_maj",
    "nb_points_ref",
    "nb_points_ocr",
    "ratio_points",
    "nb_exclam_ref",
    "nb_exclam_ocr",
    "ratio_exclam",
    "nb_quest_ref",
    "nb_quest_ocr",
    "ratio_quest",
    "ratio_punct_ref",
    "ratio_punct_ocr",
    "ratio_punct_ratio",
    "score_global"
    " ",
    "parametres_traitement",
]
display(df.head())
# Out:
#                                          fichier     wer     cer  nb_mots_ref  \
# 0      20200227_CIVIL_conclusions_MAE_page_1.txt  0.6157  0.5013          264
# 1  20210604_CIVIL_Conclusions_Thirion_page_1.txt  0.6053  0.5124          235
# 2         20130911_CIVIL_PV_GAWRONSKI_page_1.txt  0.7724  0.6054          521
# 3  20210604_CIVIL_Conclusions_Thirion_page_3.txt  0.5905  0.4657          326
# 4           20130905_CIVIL_PV_GALLORO_page_1.txt  0.7293  0.5705          535
#
#    nb_mots_ocr  ratio_mots  nb_paragraphes_ref  nb_paragraphes_ocr  \
# 0          148    0.560606                  12                  17
# 1          132    0.561702                  13                  15
# 2          313    0.600768                  25                  48
# 3          189    0.579755                  14                  15
# 4          310    0.579439                   9                  68
#
#    ratio_paragraphes  nb_maj_ref  ...  nb_exclam_ocr  ratio_exclam  \
# 0           1.416667         319  ...              0             0
# 1           1.153846         281  ...              0             0
# 2           1.920000         422  ...              1             0
# 3           1.071429         314  ...              0             0
# 4           7.555556         420  ...              1             0
#
#    nb_quest_ref  nb_quest_ocr  ratio_quest  ratio_punct_ref  ratio_punct_ocr  \
# 0             0             0     0.000000         0.022727         0.067568
# 1             0             0     0.000000         0.025532         0.015152
# 2             3             1     0.333333         0.053743         0.054313
# 3             0             0     0.000000         0.046012         0.031746
# 4             2             2     1.000000         0.074766         0.077419
#
#    ratio_punct_ratio                                  parametres_traitement
# 0           2.972973 NaN  -resize 200% -colorspace Gray -normalize -auto...
# 1           0.593434 NaN  -resize 200% -colorspace Gray -normalize -auto...
# 2           1.010612 NaN  -resize 200% -colorspace Gray -normalize -auto...
# 3           0.689947 NaN  -resize 200% -colorspace Gray -normalize -auto...
# 4           1.035484 NaN  -resize 200% -colorspace Gray -normalize -auto...
#
# [5 rows x 26 columns]

# %%
# Affichage du WER moyen par variante de prétraitement
classement = df.groupby('parametres_traitement')['wer'].mean().sort_values()
display(classement)
# Out:
# parametres_traitement
# -resize 200% -colorspace Gray -normalize -auto-threshold Otsu              0.738314
# -resize 200% -colorspace Gray -despeckle -auto-threshold Otsu              0.739271
# -resize 200% -colorspace Gray -sharpen 0x0.2 -auto-threshold Otsu          0.739943
# -resize 200% -colorspace Gray -blur 1x1 -auto-threshold Otsu               0.740529
# -resize 200% -colorspace Gray -sharpen 0x4 -auto-threshold Otsu            0.741400
# -resize 200% -colorspace Gray -normalize -contrast -auto-threshold Otsu    0.745343
# -resize 200% -colorspace Gray -auto-gamma -auto-threshold Otsu             0.868129
# -resize 200% -colorspace Gray -auto-level -lat 240x240+8% -normalize       0.898657
# Name: wer, dtype: float64

# %%
import matplotlib.pyplot as plt

# Boxplot du WER par variante
plt.figure(figsize=(12,6))
df.boxplot(column='wer', by='parametres_traitement', rot=90)
plt.title('Distribution du WER selon la variante de prétraitement')
plt.suptitle('')
plt.xlabel("Variante de prétraitement")
plt.ylabel("WER")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\damien_dous\AppData\Local\Temp\ipykernel_17036\2642400930.py:10: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
import seaborn as sns

plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x="cer", y="wer", hue="parametres_traitement", alpha=0.7)
plt.title("Dispersion CER vs WER selon la variante")
plt.xlabel("CER")
plt.ylabel("WER")
plt.legend(bbox_to_anchor=(1,1))
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,7))
sns.scatterplot(data=df, x="cer", y="wer", hue="parametres_traitement", alpha=0.7)
plt.title("Comparaison des variantes : WER vs CER")
plt.show()

# %%
if "score_global" in df.columns:
    best_score = df.loc[df.groupby("fichier")["score_global"].idxmax()]
    display(best_score)
else:
    print("Ajoute d'abord la colonne score_global dans le CSV si tu veux faire un tri pondéré.")
# Out:
# Ajoute d'abord la colonne score_global dans le CSV si tu veux faire un tri pondéré.
